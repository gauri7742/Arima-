# %% [markdown]
# <a href="https://colab.research.google.com/github/gauri7742/Arima-/blob/master/covid_19_in_india.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0d211ad3-12de-463f-a27e-e188653b9b1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d211ad3-12de-463f-a27e-e188653b9b1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"vanshu","key":"041e295d15aca95a3f8abc68bcb5e339"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d sudalairajkumar/covid19-in-india
# Out:
# ...
#   0% 0.00/273k [00:00<?, ?B/s]
# 100% 273k/273k [00:00<00:00, 37.3MB/s]

# %%
from zipfile import ZipFile
file_name="covid19-in-india.zip"
with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt
import matplotlib.pyplot as plt
df=pd.read_csv('covid_19_india.csv')
df.head()
# Out:
#    Sno      Date     Time  ... Cured Deaths Confirmed
# 0    1  30/01/20  6:00 PM  ...     0      0         1
# 1    2  31/01/20  6:00 PM  ...     0      0         1
# 2    3  01/02/20  6:00 PM  ...     0      0         2
# 3    4  02/02/20  6:00 PM  ...     0      0         3
# 4    5  03/02/20  6:00 PM  ...     0      0         3
#
# [5 rows x 9 columns]

# %%
#df=df[['Date','State/UnionTerritory','Cured','Deaths','Confirmed']]
#df.columns=['date','state','cured','deaths','confirmed']

# %%
df.head()
# Out:
#    Sno      Date     Time  ... Cured Deaths Confirmed
# 0    1  30/01/20  6:00 PM  ...     0      0         1
# 1    2  31/01/20  6:00 PM  ...     0      0         1
# 2    3  01/02/20  6:00 PM  ...     0      0         2
# 3    4  02/02/20  6:00 PM  ...     0      0         3
# 4    5  03/02/20  6:00 PM  ...     0      0         3
#
# [5 rows x 9 columns]

# %%
df.tail()
# Out:
#        Sno      Date     Time  ...   Cured Deaths Confirmed
# 5331  5332  18/08/20  8:00 AM  ...   72202    711     93937
# 5332  5333  18/08/20  8:00 AM  ...    5404     62      7409
# 5333  5334  18/08/20  8:00 AM  ...    8485    158     12493
# 5334  5335  18/08/20  8:00 AM  ...  104808   2515    158216
# 5335  5336  18/08/20  8:00 AM  ...   89703   2473    119578
#
# [5 rows x 9 columns]

# %%
today=df[df.Date=='18/08/20']

# %%
today
# Out:
#           date                                     state  ...  deaths  confimed
# 5301  18/08/20               Andaman and Nicobar Islands  ...      29      2445
# 5302  18/08/20                            Andhra Pradesh  ...    2732    296609
# 5303  18/08/20                         Arunachal Pradesh  ...       5      2741
# 5304  18/08/20                                     Assam  ...     197     79667
# 5305  18/08/20                                     Bihar  ...     468    106307
# 5306  18/08/20                                Chandigarh  ...      30      2216
# 5307  18/08/20                              Chhattisgarh  ...     150     16025
# 5308  18/08/20  Dadra and Nagar Haveli and Daman and Diu  ...       2      1908
# 5309  18/08/20                                     Delhi  ...    4214    153367
# 5310  18/08/20                                       Goa  ...     111     11994
# 5311  18/08/20                                   Gujarat  ...    2800     79710
# ...

# %%
max_confirmed_cases=today.sort_values(by="Confirmed",ascending=False)
max_confirmed_cases
# Out:
#        Sno      Date     Time  ...   Cured Deaths Confirmed
# 5320  5321  18/08/20  8:00 AM  ...  428514  20265    604358
# 5330  5331  18/08/20  8:00 AM  ...  283937   5886    343945
# 5302  5303  18/08/20  8:00 AM  ...  209100   2732    296609
# 5316  5317  18/08/20  8:00 AM  ...  148562   4062    233283
# 5334  5335  18/08/20  8:00 AM  ...  104808   2515    158216
# 5309  5310  18/08/20  8:00 AM  ...  138301   4214    153367
# 5335  5336  18/08/20  8:00 AM  ...   89703   2473    119578
# 5305  5306  18/08/20  8:00 AM  ...   76452    468    106307
# 5331  5332  18/08/20  8:00 AM  ...   72202    711     93937
# 5311  5312  18/08/20  8:00 AM  ...   62595   2800     79710
# 5304  5305  18/08/20  8:00 AM  ...   56734    197     79667
# 5328  5329  18/08/20  8:00 AM  ...   47654    887     62630
# 5325  5326  18/08/20  8:00 AM  ...   43780    353     62294
# 5312  5313  18/08/20  8:00 AM  ...   40610    550     48040
# 5319  5320  18/08/20  8:00 AM  ...   35025   1128     46385
# ...

# %%
#states with high rate of confirmed Cases
state_high_rate=max_confirmed_cases[0:5] 
state_high_rate
# Out:
#        Sno      Date     Time  ...   Cured Deaths Confirmed
# 5320  5321  18/08/20  8:00 AM  ...  428514  20265    604358
# 5330  5331  18/08/20  8:00 AM  ...  283937   5886    343945
# 5302  5303  18/08/20  8:00 AM  ...  209100   2732    296609
# 5316  5317  18/08/20  8:00 AM  ...  148562   4062    233283
# 5334  5335  18/08/20  8:00 AM  ...  104808   2515    158216
#
# [5 rows x 9 columns]
